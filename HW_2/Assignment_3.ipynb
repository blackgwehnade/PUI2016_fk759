# %%
import os as os
from pandas import Series, DataFrame
import pandas as pd
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def df():
    dfdata = os.getenv("DFDATA") + '/avwq-z233/1414245694/avwq-z233'
    dfx = pd.read_csv(dfdata)
    dfx.drop(dfx.columns[[0, 1, 2, 3, 4, 5, 6, 8]], axis=1, inplace=True)
    dfx['Medallion Agent Number'] = dfx['Medallion Agent Number'].replace('NaN',0.0)
    def df_2():
        dfx_2 = dfx.head(5)
        print dfx_2
    df_2()
df()
# Out:
#    Model Year  Medallion Agent Number
# 0        2011                     0.0
# 1        2011                     0.0
# 2        2011                   234.0
# 3        2010                   213.0
# 4        2009                   307.0

# %%
plt.figure()
plt.title('Title')
plt.xlabel('Year')
plt.ylabel('Medallion Agent Number')
plt.scatter(np.array(dfx['Model Year']), np.array(dfx['Medallion Agent Number']))
plt.show()
