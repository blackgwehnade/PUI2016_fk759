# %%
import urllib, json
import requests
url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=8fb4f0dc-8ff5-4dcf-8f53-4fde1a25b0c7&VehicleMonitoringDetailLevel=calls&LineRef=B44"
response = urllib.urlopen(url)
data = json.loads(response.read())
bus_key = '8fb4f0dc-8ff5-4dcf-8f53-4fde1a25b0c7'
bus_line = 'B44'
data
# Out:
# {u'Siri': {u'ServiceDelivery': {u'ResponseTimestamp': u'2016-09-18T12:44:08.268-04:00',
#    u'SituationExchangeDelivery': [],
#    u'VehicleMonitoringDelivery': [{u'ResponseTimestamp': u'2016-09-18T12:44:08.268-04:00',
#      u'ValidUntil': u'2016-09-18T12:45:08.268-04:00',
#      u'VehicleActivity': [{u'MonitoredVehicleJourney': {u'Bearing': 96.16045,
#         u'BlockRef': u'MTA NYCT_FB_D6-Sunday_D_FB_25680_B44-12',
#         u'DestinationName': u'FLUSHING AV via NOSTRND',
#         u'DestinationRef': u'MTA_303422',
#         u'DirectionRef': u'0',
#         u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2016-09-18',
#          u'DatedVehicleJourneyRef': u'MTA NYCT_FB_D6-Sunday-072700_B44_9'},
#         u'JourneyPatternRef': u'MTA_B440301',
#         u'LineRef': u'MTA NYCT_B44',
#         u'Monitored': True,
#         u'MonitoredCall': {u'ExpectedArrivalTime': u'2016-09-18T12:44:09.268-04:00',
#          u'ExpectedDepartureTime': u'2016-09-18T12:44:09.268-04:00',
# ...

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['MonitoredCall'].keys()
# Out:
# [u'VisitNumber',
#  u'StopPointRef',
#  u'ExpectedDepartureTime',
#  u'StopPointName',
#  u'Extensions',
#  u'ExpectedArrivalTime']

# %%
# setting up some preferences
# %pylab inline

np.set_printoptions(precision=4, threshold=500)
np.random.seed(123321)
pl.rc('figure', figsize=(10, 6))
pd.options.display.max_rows = 100
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df1 = DataFrame({'key': ['cheese', 'pandas', 'a', 'c', 'a', 'a', 'b'], 'data1': range(7)})

# %%
df2 = DataFrame({'key': ['a', 'b', 'd'], 'data2': range(3)})

# %%
df1
# Out:
#    data1     key
# 0      0  cheese
# 1      1  pandas
# 2      2       a
# 3      3       c
# 4      4       a
# 5      5       a
# 6      6       b

# %%
df2
# Out:
#    data2 key
# 0      0   a
# 1      1   b
# 2      2   d
