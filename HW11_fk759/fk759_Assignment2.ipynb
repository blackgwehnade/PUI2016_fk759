# %%
import os
import zipfile
import numpy as np
import pandas as pd
import json
import urllib as ulr
import seaborn as sns
import shapely
import geopandas as gp
import scipy.stats as sp
import matplotlib.pylab as plt
import sklearn
import sklearn.cluster as cluster
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn import mixture
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_samples, silhouette_score
# %matplotlib inline

# %% [markdown]
# **Curl Business Data from US Census URL and move to PUIDATA folder**

# %% [markdown]
# WARNING!!! Do NOT run the cell below if you already have data stored locally as it will take a LONG time.
# Instead, manually download to a local directory and adjust my data paths below accordingly.

# %%
os.system("curl -O ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp00totals.zip")
os.system("curl -O ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp01totals.zip")
os.system("curl -O ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp94totals.zip")
os.system("curl -O ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp95totals.zip")
os.system("curl -O ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp96totals.zip")
os.system("curl -O ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp97totals.zip")
os.system("curl -O ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp96totals.zip")
os.system("curl -O ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp97totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2002/CBP_CSV/zbp02totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2003/CBP_CSV/zbp03totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2004/CBP_CSV/zbp04totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2005/CBP_CSV/zbp05totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2006/CBP_CSV/zbp06totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2007/CBP_CSV/zbp07totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2008/CBP_CSV/zbp08totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2009/CBP_CSV/zbp09totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2010/CBP_CSV/zbp10totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2011/CBP_CSV/zbp11totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2012/CBP_CSV/zbp12totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2013/CBP_CSV/zbp13totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2014/CBP_CSV/zbp14totals.zip")
os.system("curl -O ftp://ftp.census.gov/econ2015/CBP_CSV/zbp15totals.zip")

os.system("unzip " + "zbp00totals.zip")
os.system("unzip " + "zbp01totals.zip")
os.system("unzip " + "zbp94totals.zip")
os.system("unzip " + "zbp95totals.zip")
os.system("unzip " + "zbp96totals.zip")
os.system("unzip " + "zbp97totals.zip")
os.system("unzip " + "zbp96totals.zip")
os.system("unzip " + "zbp97totals.zip")
os.system("unzip " + "zbp02totals.zip")
os.system("unzip " + "zbp03totals.zip")
os.system("unzip " + "zbp04totals.zip")
os.system("unzip " + "zbp05totals.zip")
os.system("unzip " + "zbp06totals.zip")
os.system("unzip " + "zbp07totals.zip")
os.system("unzip " + "zbp08totals.zip")
os.system("unzip " + "zbp09totals.zip")
os.system("unzip " + "zbp10totals.zip")
os.system("unzip " + "zbp11totals.zip")
os.system("unzip " + "zbp12totals.zip")
os.system("unzip " + "zbp13totals.zip")
os.system("unzip " + "zbp14totals.zip")
os.system("unzip " + "zbp15totals.zip")

os.system("rm " + "zbp00totals.zip")
os.system("rm " + "zbp01totals.zip")
os.system("rm " + "zbp94totals.zip")
os.system("rm " + "zbp95totals.zip")
os.system("rm " + "zbp96totals.zip")
os.system("rm " + "zbp97totals.zip")
os.system("rm " + "zbp96totals.zip")
os.system("rm " + "zbp97totals.zip")
os.system("rm " + "zbp02totals.zip")
os.system("rm " + "zbp03totals.zip")
os.system("rm " + "zbp04totals.zip")
os.system("rm " + "zbp05totals.zip")
os.system("rm " + "zbp06totals.zip")
os.system("rm " + "zbp07totals.zip")
os.system("rm " + "zbp08totals.zip")
os.system("rm " + "zbp09totals.zip")
os.system("rm " + "zbp10totals.zip")
os.system("rm " + "zbp11totals.zip")
os.system("rm " + "zbp12totals.zip")
os.system("rm " + "zbp13totals.zip")
os.system("rm " + "zbp14totals.zip")
os.system("rm " + "zbp15totals.zip")

os.system("mv " + "zbp00totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp01totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp94totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp95totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp96totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp97totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp98totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp99totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp02totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp03totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp04totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp05totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp06totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp07totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp08totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp09totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp10totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp11totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp12totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp13totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp14totals.txt " + os.getenv("PUIDATA"))
os.system("mv " + "zbp15totals.txt " + os.getenv("PUIDATA"))

os.system("curl -O https://github.com/fedhere/PUI2016_fb55/blob/master/HW11_fb55/nyc-zip-code-tabulation-areas-polygons.geojson")
os.system("unzip " + "nyc-zip-code-tabulation-areas-polygons.geojson")
os.system("rm " + "nyc-zip-code-tabulation-areas-polygons.geojson")
os.system("mv " + "nyc-zip-code-tabulation-areas-polygons.geojson " + os.getenv("PUIDATA"))

# %%
df_94 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp94totals.txt")
df_95 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp95totals.txt")
df_96 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp96totals.txt")
df_97 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp97totals.txt")
df_98 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp98totals.txt")
df_99 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp99totals.txt")
df_00 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp00totals.txt")
df_01 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp01totals.txt")
df_02 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp02totals.txt")
df_03 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp03totals.txt")
df_04 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp04totals.txt")
df_05 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp05totals.txt")
df_06 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp06totals.txt")
df_07 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp07totals.txt")
df_08 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp08totals.txt")
df_09 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp09totals.txt")
df_10 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp10totals.txt")
df_11 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp11totals.txt")
df_12 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp12totals.txt")
df_13 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp13totals.txt")
df_14 = pd.read_csv(os.getenv("PUIDATA") + "/" + "zbp14totals.txt")

# %% [markdown]
# **Now to Wrangle the GeoJSON Data** *(curled from Github Repo of Federica Bianco)*

# %%
url = "https://raw.githubusercontent.com/fedhere/PUI2016_fb55/master/HW11_fb55/nyc-zip-code-tabulation-areas-polygons.geojson" 
response = ulr.urlopen(url)
data = response.read().decode("utf-8")
data = json.loads(data)

# %%
def get_geojson(json):
    """
    A function that retrieves information needed from the json data file and creates a dataframe
    """
    df=pd.DataFrame()
    df['geometry']=[]
    df['PO_NAME']=[]
    df['Shape_Leng']=[]
    df['Shape_Area']=[]
    df['borough']=[]
    df['postalCode']=[]
    
    for i in range(262):
        df = df.append({'geometry': (data['features'][i]['geometry']['coordinates'][0]),
                        'PO_NAME' : data['features'][i]['properties']['PO_NAME'],
                        'Shape_Area' : data['features'][i]['properties']['Shape_Area'],
                        'Shape_Leng' : data['features'][i]['properties']['Shape_Leng'],
                        'borough' : data['features'][i]['properties']['borough'],
                        'postalCode' : data['features'][i]['properties']['postalCode']
                       },ignore_index=True)

    return df

# %%
dfg=get_geojson(data['features'])

# %%
dfg=gp.GeoDataFrame(dfg)

# %%
dfg.columns=['geometry', 'PO_NAME', 'Shape_Leng', 'Shape_Area', 'borough',
       'zip']

# %%
dfg.head()
# Out:
#                                             geometry          PO_NAME  \
# 0  [[-73.8694245728, 40.749156871], [-73.89507143...  Jackson Heights
# 1  [[-73.7106837407, 40.7500403945], [-73.7086939...        Glen Oaks
# 2  [[-73.7009827863, 40.7388956992], [-73.7030872...    New Hyde Park
# 3  [[-73.7227044714, 40.7537337144], [-73.7225062...        Bellerose
# 4  [[-73.8108863474, 40.7271718758], [-73.8111563...    Fresh Meadows
#
#      Shape_Leng    Shape_Area borough    zip
# 0  20624.692317  2.016328e+07  Queens  11372
# 1  23002.816039  2.260653e+07  Queens  11004
# 2  15749.161511  6.269333e+06  Queens  11040
# 3  35932.810639  4.941836e+07  Queens  11426
# 4  38693.565676  6.938587e+07  Queens  11365

# %% [markdown]
# **Prepare Business ZIP Data to merge**

# %%
df_94=df_94.iloc[:,[0,6]]
df_95=df_95.iloc[:,[0,6]]
df_96=df_96.iloc[:,[0,6]]
df_97=df_97.iloc[:,[0,6]]
df_98=df_98.iloc[:,[0,6]]
df_99=df_99.iloc[:,[0,6]]
df_00=df_00.iloc[:,[0,6]]
df_01=df_01.iloc[:,[0,6]]
df_02=df_02.iloc[:,[0,6]]
df_03=df_03.iloc[:,[0,6]]
df_04=df_04.iloc[:,[0,6]]
df_05=df_05.iloc[:,[0,6]]
df_06=df_06.iloc[:,[0,6]]
df_07=df_07.iloc[:,[0,9]]
df_08=df_08.iloc[:,[0,9]]
df_09=df_09.iloc[:,[0,9]]
df_10=df_10.iloc[:,[0,9]]
df_11=df_11.iloc[:,[0,9]]
df_12=df_12.iloc[:,[0,9]]
df_13=df_13.iloc[:,[0,9]]
df_14=df_14.iloc[:,[0,9]]

# %%
df_98.columns=['zip','est']
df_99.columns=['zip','est']
df_00.columns=['zip','est']
df_01.columns=['zip','est']
df_02.columns=['zip','est']

# %% [markdown]
# **Actually Merge Data**

# %%
#Make a list from all business ZIP dataframes
bus_list=[df_94,df_95,df_96,df_97,df_98,df_99,df_00,df_01,df_02,df_03,df_04,
     df_05,df_06,df_07,df_08,df_09,df_10,df_11,df_12,df_13,df_14]

for i in bus_list:
    if 'zip' in i.columns:
        i['zip']=i['zip'].astype(str)
        dfg = pd.merge(left =  dfg, 
                             right= i, 
                             how = 'left', 
                             on = 'zip')

# %%
#Build a list to rename df columns
df_columns=['geometry', 'PO_NAME', 'Shape_Leng', 'Shape_Area', 'borough', 'zip']
years=range(1994,2015)
for i in years:
    df_columns.append(str(i))

# %%
dfg.columns=df_columns
dfg.head()
# Out:
#                                             geometry          PO_NAME  \
# 0  [[-73.8694245728, 40.749156871], [-73.89507143...  Jackson Heights
# 1  [[-73.7106837407, 40.7500403945], [-73.7086939...        Glen Oaks
# 2  [[-73.7009827863, 40.7388956992], [-73.7030872...    New Hyde Park
# 3  [[-73.7227044714, 40.7537337144], [-73.7225062...        Bellerose
# 4  [[-73.8108863474, 40.7271718758], [-73.8111563...    Fresh Meadows
#
#      Shape_Leng    Shape_Area borough    zip    1994    1995    1996    1997  \
# 0  20624.692317  2.016328e+07  Queens  11372  1229.0  1236.0  1292.0  1309.0
# 1  23002.816039  2.260653e+07  Queens  11004   194.0   188.0   176.0   192.0
# 2  15749.161511  6.269333e+06  Queens  11040  1422.0  1414.0  1335.0  1344.0
# 3  35932.810639  4.941836e+07  Queens  11426   326.0   219.0   209.0   198.0
# 4  38693.565676  6.938587e+07  Queens  11365   492.0   476.0   483.0   522.0
#
#     ...      2005    2006    2007    2008    2009    2010    2011    2012  \
# ...

# %%
dfg.iloc[:, 6:].describe()
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#               1994         1995         1996         1997         1998  \
# count   255.000000   251.000000   252.000000   252.000000   252.000000
# mean    753.301961   780.446215   787.369048   806.873016   818.666667
# std    1126.814763  1159.086499  1160.771736  1185.509721  1196.503868
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%            NaN          NaN          NaN          NaN          NaN
# 50%            NaN          NaN          NaN          NaN          NaN
# 75%            NaN          NaN          NaN          NaN          NaN
# max    6999.000000  7088.000000  7075.000000  7154.000000  7254.000000
#
#               1999         2000         2001         2002         2003  \
# count   249.000000   253.000000   253.000000   252.000000   252.000000
# ...

# %% [markdown]
# **Data Whitening Phase**

# %%
for year in dfg.iloc[:, 6:]:
    for i in range(0, len(dfg)):
        dfg[year][i] = ((dfg[year][i] - dfg[year].mean()) / dfg[year].std())
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
dfg.head()
# Out:
#                                             geometry          PO_NAME  \
# 0  [[-73.8694245728, 40.749156871], [-73.89507143...  Jackson Heights
# 1  [[-73.7106837407, 40.7500403945], [-73.7086939...        Glen Oaks
# 2  [[-73.7009827863, 40.7388956992], [-73.7030872...    New Hyde Park
# 3  [[-73.7227044714, 40.7537337144], [-73.7225062...        Bellerose
# 4  [[-73.8108863474, 40.7271718758], [-73.8111563...    Fresh Meadows
#
#      Shape_Leng    Shape_Area borough    zip      1994      1995      1996  \
# 0  20624.692317  2.016328e+07  Queens  11372  0.422162  0.393028  0.434737
# 1  23002.816039  2.260653e+07  Queens  11004 -0.491826 -0.506587 -0.522000
# 2  15749.161511  6.269333e+06  Queens  11040  0.597849  0.550958  0.476376
# 3  35932.810639  4.941836e+07  Queens  11426 -0.368922 -0.474045 -0.488033
# 4  38693.565676  6.938587e+07  Queens  11365 -0.220497 -0.251732 -0.251477
#
#        1997    ...         2005      2006      2007      2008      2009  \
# ...

# %% [markdown]
# **Compiling Statistical Information on new DF**

# %%
dfg.iloc[:, 6:].mean()
# Out:
# 1994    0.773241
# 1995    0.766681
# 1996    0.785010
# 1997    0.800471
# 1998    0.795113
# 1999    0.805850
# 2000    0.859727
# 2001    0.868568
# 2002    0.887269
# 2003    0.891574
# 2004    0.882743
# 2005    0.846061
# 2006    0.867578
# 2007    0.892123
# 2008    0.904146
# 2009    0.928636
# 2010    0.925212
# 2011    0.932719
# 2012    0.941984
# 2013    0.947037
# 2014    0.961125
# dtype: float64

# %%
dfg.iloc[:, 6:].std()
# Out:
# 1994    2.011375
# 1995    2.015350
# 1996    2.039033
# 1997    2.130678
# 1998    2.125079
# 1999    2.145035
# 2000    2.297194
# 2001    2.317076
# 2002    2.294902
# 2003    2.285603
# 2004    2.196610
# 2005    2.077841
# 2006    2.085088
# 2007    2.252537
# 2008    2.282440
# 2009    2.325688
# 2010    2.307882
# 2011    2.318264
# 2012    2.320021
# 2013    2.314552
# 2014    2.341915
# dtype: float64

# %% [markdown]
# **Making the Cluster**

# %%
dfg.dropna(inplace=True)

# %%
scaled_data = dfg.iloc[:, 6:]

# %%
#Calculate the Silhouette Score to decide the number of clusters
X=scaled_data
range_n_clusters = [3, 4, 5, 6, 7, 8, 9]
for n_clusters in range_n_clusters:
    km = sklearn.cluster.KMeans(n_clusters=n_clusters, random_state=324) #the clustering model we choose (HH)
    cluster_labels = km.fit_predict(X)
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters ={},".format(n_clusters)+" the average silhouette_score is :{}".format(silhouette_avg))
# Out:
# For n_clusters =3, the average silhouette_score is :0.753489486768
# For n_clusters =4, the average silhouette_score is :0.671902442094
# For n_clusters =5, the average silhouette_score is :0.594185016254
# For n_clusters =6, the average silhouette_score is :0.61120128493
# For n_clusters =7, the average silhouette_score is :0.606026607773
# For n_clusters =8, the average silhouette_score is :0.618105892432
# For n_clusters =9, the average silhouette_score is :0.622254575343

# %%
'''
We've opted to have 3 clusters, since the average silhouette score after running the cell above
was highest at n=3
'''
n=3 

#Kmeans
KM=cluster.KMeans(n_clusters=n)
KM.fit(scaled_data)
res_KM=KM.predict(scaled_data)

#merge the result with zipcodes for graph plotting
res_KM=pd.concat((dfg.loc[:, 'zip'],pd.DataFrame(res_KM)),axis=1)
res_KM.columns = ['zip', 'cluster']
res_KM.head()
# Out:
#      zip  cluster
# 0  11372      0.0
# 1  11004      0.0
# 2  11040      0.0
# 3  11426      0.0
# 4  11365      0.0

# %%
print 'Number of zipcodes in first cluster: %d' %res_KM.groupby('cluster').size()[0]
print 'Number of zipcodes in second cluster: %d' %res_KM.groupby('cluster').size()[1]
print 'Number of zipcodes in third cluster: %d' %res_KM.groupby('cluster').size()[2]
# Out:
# Number of zipcodes in first cluster: 211
# Number of zipcodes in second cluster: 4
# Number of zipcodes in third cluster: 28

# %%
dfg = pd.merge(left=dfg, right=res_KM, how='left', on='zip')

# %%
dfg.plot(c=dfg.cluster)
